# %% [markdown]
# # Raw Data

# %%
import pandas as pd
import numpy as np

# Load raw_data sheet from data.xlsx file
df = pd.read_excel('data.xlsx', sheet_name='raw_data')

df.head()
# Out:
#   Country Name  Agriculture, forestry, and fishing, value added (% of GDP)  \
# 0      Algeria                                          11.896481
# 1    Argentina                                           5.837215
# 2    Australia                                           2.320361
# 3      Austria                                           1.154085
# 4      Bahrain                                           0.297562
#
#    Births attended by skilled health staff (% of total)  \
# 0                                          21.711111
# 1                                          87.377778
# 2                                          77.033333
# 3                                          87.466667
# 4                                          77.588889
#
#    CO2 emissions (metric tons per capita)  \
# 0                                3.007712
# 1                                3.204716
# 2                               12.292316
# 3                                5.725834
# 4                               17.092581
#
#    Foreign direct investment, net inflows (BoP, current US$)  \
# 0                                       1.365376e+09
# 1                                       7.921553e+09
# 2                                       4.394122e+10
# 3                                       7.002187e+09
# 4                                       1.163688e+09
#
#    GDP (current US$)  GDP growth (annual %)  \
# 0       1.749342e+11               2.562500
# 1       5.243996e+11               4.588309
# 2       1.403075e+12               2.451737
# 3       4.314502e+11               1.806114
# 4       3.497043e+10               3.325642
#
#    GNI per capita, Atlas method (current US$)  \
# 0                                 4402.222222
# 1                                11755.555556
# 2                                57342.222222
# 3                                49068.888889
# 4                                20694.444444
#
#    Industry (including construction), value added (% of GDP)  \
# 0                                          37.676550
# 1                                          23.101116
# 2                                          24.518168
# 3                                          25.457618
# 4                                          42.788784
#
#    Life expectancy at birth, total (years)  Population growth (annual %)  \
# 0                                75.576889                      1.892119
# 1                                76.523556                      1.035293
# 2                                82.660705                      1.357655
# 3                                81.457995                      0.672281
# 4                                79.448333                      2.838455
#
#    Poverty headcount ratio at $2,15 a day (2017 PPP) (% of population)  \
# 0                                           0.000000
# 1                                           0.666667
# 2                                           0.166667
# 3                                           0.455556
# 4                                           0.000000
#
#    Revenue, excluding grants (% of GDP)  \
# 0                              0.000000
# 1                             19.846545
# 2                             25.117536
# 3                             44.199627
# 4                              0.000000
#
#    Time required to start a business (days)
# 0                                 14.666667
# 1                                 16.111111
# 2                                  1.888889
# 3                                 17.000000
# 4                                  6.811111

# %% [markdown]
# # Normalized data
#
# the method used to normalize values : min max
#
# value = (value - min) / (max - min)
#
# A total of 12 metrics, 10 metrics should be maximize, and 2 minimized
#
# in order to normalize the values in the matrix that should be maximized : value = 1 - [(value - min) / (max - min)]

# %%
# Load normalized_data sheet from data.xlsx file



normalized_df = pd.read_excel('data.xlsx', sheet_name='normalized_data')

normalized_df.head()
# Out:
#   Country Name  Agriculture, forestry, and fishing, value added (% of GDP)  \
# 0      Algeria                                           0.709224
# 1    Argentina                                           0.347001
# 2    Australia                                           0.136764
# 3      Austria                                           0.067044
# 4      Bahrain                                           0.015842
#
#    Births attended by skilled health staff (% of total)  \
# 0                                           0.146982
# 1                                           0.983038
# 2                                           0.851335
# 3                                           0.984170
# 4                                           0.858408
#
#    CO2 emissions (metric tons per capita)(MAX)  \
# 0                                     0.916817
# 1                                     0.909153
# 2                                     0.555634
# 3                                     0.811079
# 4                                     0.368897
#
#    Foreign direct investment, net inflows (BoP, current US$)  \
# 0                                           0.002728
# 1                                           0.022206
# 2                                           0.129220
# 3                                           0.019475
# 4                                           0.002129
#
#    GDP (current US$)  GDP growth (annual %)  \
# 0           0.008210               0.216477
# 1           0.025985               0.542867
# 2           0.070679               0.198631
# 3           0.021257               0.094611
# 4           0.001091               0.339431
#
#    GNI per capita, Atlas method (current US$)  \
# 0                                    0.030573
# 1                                    0.116965
# 2                                    0.652551
# 3                                    0.555350
# 4                                    0.221986
#
#    Industry (including construction), value added (% of GDP)  \
# 0                                           0.544319
# 1                                           0.244504
# 2                                           0.273653
# 3                                           0.292977
# 4                                           0.649477
#
#    Life expectancy at birth, total (years)  Population growth (annual %)  \
# 0                                 0.569408                      0.442939
# 1                                 0.617566                      0.311875
# 2                                 0.929770                      0.361185
# 3                                 0.868587                      0.256347
# 4                                 0.766353                      0.587695
#
#    Poverty headcount ratio at $2,15 a day MAX  Revenue, excluding grants  \
# 0                                    1.000000                   0.000000
# 1                                    0.915849                   0.422798
# 2                                    0.978962                   0.535088
# 3                                    0.942496                   0.941600
# 4                                    1.000000                   0.000000
#
#    Time required to start a business (days)
# 0                                  0.288273
# 1                                  0.316663
# 2                                  0.037126
# 3                                  0.334134
# 4                                  0.133872

# %% [markdown]
# # Ordered Weighted Averages Operator
#
# ### the weights given by the decision maker :
#
# w = (0.05, 0.03, 0.05, 0.05, 0.009, 0.09, 0.1, 0.14, 0.03, 0.02, 0.04, 0.06, 0.091, 0.04, 0.02, 0.18)

# %%
weights = np.array([0.09, 0.01, 0.03, 0.05, 0.001, 0.09, 0.16, 0.08, 0.03, 0.02, 0.06, 0.04, 0.09, 0.04, 0.029, 0.18])


print("The sum of all the weights : ", end='')
print(sum(weights))
# Out:
# The sum of all the weights : 1.0

# %% [markdown]
# ### Calcul des scores

# %%
data_set = normalized_df.to_numpy()


# array to store the calculated weighted values
averages = np.zeros(data_set.shape[0])

# calcul
for i in range(len(data_set)):
    res = 0
    for j in range(1, data_set.shape[1]):
        res += data_set[i][j] * weights[j]
    averages[i]= res

# %% [markdown]
# ## Ranking of the countries

# %%
ranking = list()

temp_averages = averages
max_index = np.argmax(temp_averages)
ranking.append(max_index)

for i in range(len(data_set)-1):
    temp_averages[max_index] = -9999
    max_index = np.argmax(temp_averages)
    ranking.append(max_index)

for i in range(len(ranking)):
    print(f'Choice number {i} : {data_set[ranking[i]][0]}')
# Out:
# Choice number 0 : China
# Choice number 1 : Norway
# Choice number 2 : Luxembourg
# Choice number 3 : Israel
# Choice number 4 : Turkiye
# Choice number 5 : United States
# Choice number 6 : Japan
# Choice number 7 : Singapore
# Choice number 8 : Sweden
# Choice number 9 : Croatia
# Choice number 10 : India
# Choice number 11 : Qatar
# Choice number 12 : Austria
# Choice number 13 : Denmark
# Choice number 14 : United Kingdom
# Choice number 15 : Netherlands
# Choice number 16 : France
# Choice number 17 : Argentina
# Choice number 18 : Switzerland
# Choice number 19 : Peru
# Choice number 20 : Finland
# Choice number 21 : Italy
# Choice number 22 : Paraguay
# Choice number 23 : Belgium
# Choice number 24 : Australia
# Choice number 25 : Portugal
# Choice number 26 : Greece
# Choice number 27 : Germany
# Choice number 28 : Spain
# Choice number 29 : Saudi Arabia
# Choice number 30 : Indonesia
# Choice number 31 : Korea, Rep,
# Choice number 32 : Brazil
# Choice number 33 : Canada
# Choice number 34 : Malta
# Choice number 35 : Bulgaria
# Choice number 36 : Uruguay
# Choice number 37 : United Arab Emirates
# Choice number 38 : Egypt, Arab Rep,
# Choice number 39 : Bahrain
# Choice number 40 : Mexico
# Choice number 41 : Kuwait
# Choice number 42 : Algeria
# Choice number 43 : South Africa
# Choice number 44 : Cuba
# Choice number 45 : Tunisia
